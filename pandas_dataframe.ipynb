# %%
import pandas as pd

# %%
import numpy as np

# %%
labels=['a','b','c']
my_list=['10','20','30']

# %%
my_list
# Out:
# ['10', '20', '30']

# %%
labels
# Out:
# ['a', 'b', 'c']

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: object

# %%
labels=['a','b','c','d']
my_list=[10,20,30,40]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
arr=[10,20,30,40]
arr

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
d={1:10,2:20,3:30,4:40,5:50,6:60}
d

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
import pandas as pd

# %% [raw]
# import numpy as np

# %%
l=['a','b','c','d','e']
list=[10,20,30,40,50]
arr=np.array([23,24,25,25,26])
d={
    'a':10,'b':20,'c':30,
    'd':40,'e':50
}

# %%
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
import numpy as np

# %%
arr=np.array([10,20,30,40,50])
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series(list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
pd.Series(list,index=l)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
l=['a','b','c','d','e','f']
l

# %%
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
pd.Series(l,index=l)
# Out:
# a    a
# b    b
# c    c
# d    d
# e    e
# dtype: object

# %%
# Data Frame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df['Salary']
# Out:
# 0    65000
# 1    70000
# 2    62000
# 3    85000
# Name: Salary, dtype: int64

# %%
d = [
     ['John', 'Anna', 'Peter', 'Linda'],
     [28, 34, 29, 42],
     ['New York', 'Paris', 'Berlin', 'London'],
     [65000, 70000, 62000, 85000]
]
    
    
df = pd.DataFrame(d)

# %%
df
# Out:
#           0      1       2       3
# 0      John   Anna   Peter   Linda
# 1        28     34      29      42
# 2  New York  Paris  Berlin  London
# 3     65000  70000   62000   85000

# %%
import pandas as pd

# %%
data_list= [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list= [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
rows = ["21","22","23","24"]
df2 = pd.DataFrame(data_list,index = rows)
df2
# Out:
#         0   1         2      3
# 21   John  28  New York  65000
# 22   Anna  34     Paris  70000
# 23  Peter  29    Berlin  62000
# 24  Linda  42    London  85000

# %%
data_list= [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
rows = ["a","b","c","d"]
df2 = pd.DataFrame(data_list,index = rows)
df2
# Out:
#        0   1         2      3
# a   John  28  New York  65000
# b   Anna  34     Paris  70000
# c  Peter  29    Berlin  62000
# d  Linda  42    London  85000

# %%
df2
# Out:
#        0   1         2      3
# a   John  28  New York  65000
# b   Anna  34     Paris  70000
# c  Peter  29    Berlin  62000
# d  Linda  42    London  85000

# %%
df2
# Out:
#        0   1         2      3
# a   John  28  New York  65000
# b   Anna  34     Paris  70000
# c  Peter  29    Berlin  62000
# d  Linda  42    London  85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[['Name','Age']]
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df2[['Salary','City']]
# Out:
#    Salary      City
# 0   65000  New York
# 1   70000     Paris
# 2   62000    Berlin
# 3   85000    London

# %%
df2[['Salary', 'City']]
# Out:
#    Salary    City
# 1   70000   Paris
# 2   62000  Berlin
# 3   85000  London

# %%
df2['Designation']=['d','e','d','e']
df2['Designation']
# Out:
# 0    d
# 1    e
# 2    d
# 3    e
# Name: Designation, dtype: object

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000           d
# 1   Anna   34     Paris   70000           e
# 2  Peter   29    Berlin   62000           d
# 3  Linda   42    London   85000           e

# %%
df2["Designation"] = ["Doctor","Eng.","Doctor","Eng."]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2["Designation"] = ["Doctor","Eng.","Doctor","Eng."]
df2["Designation"]
# Out:
# 0    Doctor
# 1      Eng.
# 2    Doctor
# 3      Eng.
# Name: Designation, dtype: object

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2[['Salary','City']]
# Out:
#    Salary    City
# 1   70000   Paris
# 2   62000  Berlin
# 3   85000  London

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000        Eng.
# 2  Peter   29  Berlin   62000      Doctor
# 3  Linda   42  London   85000        Eng.

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop('Name',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df2.drop('Name',axis=1)
#
# File D:\Anaconda\Anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df2
# Out:
#    Age    City  Salary Designation
# 1   34   Paris   70000        Eng.
# 2   29  Berlin   62000      Doctor
# 3   42  London   85000        Eng.

# %%
df2.drop('Age',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df2.drop('Age',axis=1,inplace=True)
#
# File D:\Anaconda\Anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df2
# Out:
#      City  Salary Designation
# 1   Paris   70000        Eng.
# 2  Berlin   62000      Doctor
# 3  London   85000        Eng.

# %%
df2.loc[0]
# Out:
# Name               John
# Age                  28
# City           New York
# Salary            65000
# Designation      Doctor
# Name: 0, dtype: object

# %%
df2.loc[1]
# Out:
# Name            Anna
# Age               34
# City           Paris
# Salary         70000
# Designation     Eng.
# Name: 1, dtype: object

# %%
df2.loc[2]
# Out:
# Name            Peter
# Age                29
# City           Berlin
# Salary          62000
# Designation    Doctor
# Name: 2, dtype: object

# %%
df2.loc[3]
# Out:
# Name            Linda
# Age                42
# City           London
# Salary          85000
# Designation      Eng.
# Name: 3, dtype: object

# %%
df2.loc[[0,1,2]]
# Out:
#     Name  Age      City  Salary id
# 0   John   28  New York   65000  1
# 1   Anna   34     Paris   70000  2
# 2  Peter   29    Berlin   62000  3

# %%
df2.loc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# id             4
# Name: 3, dtype: object

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# id             4
# Name: 3, dtype: object

# %%
df2.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2[['Salary','City']]
# Out:
#    Salary      City
# 0   65000  New York
# 1   70000     Paris
# 2   62000    Berlin
# 3   85000    London

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000        Eng.
# 2  Peter   29  Berlin   62000      Doctor
# 3  Linda   42  London   85000        Eng.

# %%
df2.drop(2,axis=0)
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop(1,axis=0)
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop(2,axis=0)
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 3  Linda   42    London   85000        Eng.

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop(0,axis=0,inplace=True)

# %%
df2.drop('Name',axis=1)
# Out:
#    Age      City  Salary id
# 0   28  New York   65000  1
# 1   34     Paris   70000  2
# 2   29    Berlin   62000  3
# 3   42    London   85000  4

# %%
df2
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000        Eng.
# 2  Peter   29  Berlin   62000      Doctor
# 3  Linda   42  London   85000        Eng.

# %%
df.loc[[1,2]][['Age','City']]
# Out:
#    Age    City
# 1   34   Paris
# 2   29  Berlin

# %%
df2.loc[1]['Age']
# Out:
# np.int64(34)

# %%
df2.loc[2]['Salary']
# Out:
# np.int64(62000)

# %%
df2.loc[[2,3]],[['Age','Salary']]
# Out:
# (    Name  Age    City  Salary Designation
#  2  Peter   29  Berlin   62000      Doctor
#  3  Linda   42  London   85000        Eng.,
#  [['Age', 'Salary']])

# %%
df2.loc[[2,3]][['Age','Salary']]
# Out:
#    Age  Salary
# 2   29   62000
# 3   42   85000

# %%
df2['Age']
# Out:
# 1    34
# 2    29
# 3    42
# Name: Age, dtype: int64

# %%
df2[(df2['Age']>30)]
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000        Eng.
# 3  Linda   42  London   85000        Eng.

# %%
df2[(df2['Age']<30)]
# Out:
#     Name  Age    City  Salary Designation
# 2  Peter   29  Berlin   62000      Doctor

# %%
df2[(df2['Age']>30)&(df2['City']=='Paris')]
# Out:
#    Name  Age   City  Salary Designation
# 1  Anna   34  Paris   70000        Eng.

# %%
df2['id']=['1','2','3','4']
df2['id']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: id, dtype: object

# %%
df2
# Out:
#     Name  Age      City  Salary id
# 0   John   28  New York   65000  1
# 1   Anna   34     Paris   70000  2
# 2  Peter   29    Berlin   62000  3
# 3  Linda   42    London   85000  4

# %%
data_list = [
    ['Pawan', 25, 'Pune', 50000],
    ['Neha', 27, 'Mumbai', 60000],
    ['Amit', 29, 'Delhi', 55000]
]

print(data_list)
df4=pd.DataFrame(data_list)
df4
# Out:
# [['Pawan', 25, 'Pune', 50000], ['Neha', 27, 'Mumbai', 60000], ['Amit', 29, 'Delhi', 55000]]
#        0   1       2      3
# 0  Pawan  25    Pune  50000
# 1   Neha  27  Mumbai  60000
# 2   Amit  29   Delhi  55000

# %%
data_list = [
    ['Pawan', 25, 'Pune', 50000],
    ['Neha', 27, 'Mumbai', 60000],
    ['Amit', 29, 'Delhi', 55000]
]

print(data_list)
df4=pd.DataFrame(data_list)
df4
columns=['Name','Age','City','Salary']
df5=pd.DataFrame(data_list,columns=columns)
df5
# Out:
# [['Pawan', 25, 'Pune', 50000], ['Neha', 27, 'Mumbai', 60000], ['Amit', 29, 'Delhi', 55000]]
#     Name  Age    City  Salary
# 0  Pawan   25    Pune   50000
# 1   Neha   27  Mumbai   60000
# 2   Amit   29   Delhi   55000

# %%
df4=pd.DataFrame(data_list)
rows=['a','b','c']
df4=pd.DataFrame(data_list,index=rows)
df4
# Out:
#        0   1       2      3
# a  Pawan  25    Pune  50000
# b   Neha  27  Mumbai  60000
# c   Amit  29   Delhi  55000

# %%
df5
# Out:
#     Name  Age    City  Salary
# 0  Pawan   25    Pune   50000
# 1   Neha   27  Mumbai   60000
# 2   Amit   29   Delhi   55000

# %%
df5.drop(0,axis=0)
# Out:
#    Name  Age    City  Salary
# 1  Neha   27  Mumbai   60000
# 2  Amit   29   Delhi   55000

# %%
df5
# Out:
#     Name  Age    City  Salary
# 0  Pawan   25    Pune   50000
# 1   Neha   27  Mumbai   60000
# 2   Amit   29   Delhi   55000

# %%
df5.drop(0,axis=0,inplace=True)

# %%
df5
# Out:
#    Name  Age    City  Salary
# 1  Neha   27  Mumbai   60000
# 2  Amit   29   Delhi   55000

# %%
data_list = [
    ['Pawan', 25, 'Pune', 50000],
    ['Neha', 27, 'Mumbai', 60000],
    ['Amit', 29, 'Delhi', 55000]
]

print(data_list)
df8=pd.DataFrame(data_list)
df8
# Out:
# [['Pawan', 25, 'Pune', 50000], ['Neha', 27, 'Mumbai', 60000], ['Amit', 29, 'Delhi', 55000]]
#        0   1       2      3
# 0  Pawan  25    Pune  50000
# 1   Neha  27  Mumbai  60000
# 2   Amit  29   Delhi  55000

# %%
df8=pd.DataFrame(data_list)
df8
columns=['Name','Age','City','Salary']
df8=pd.DataFrame(data_list,columns=columns)
df8
# Out:
#     Name  Age    City  Salary
# 0  Pawan   25    Pune   50000
# 1   Neha   27  Mumbai   60000
# 2   Amit   29   Delhi   55000

# %%
df8.loc[0]
# Out:
# Name      Pawan
# Age          25
# City       Pune
# Salary    50000
# Name: 0, dtype: object

# %%
df8.loc[[0,1]]
# Out:
#     Name  Age    City  Salary
# 0  Pawan   25    Pune   50000
# 1   Neha   27  Mumbai   60000

# %%
df8.loc[[1,2]][['City','Salary']]
# Out:
#      City  Salary
# 1  Mumbai   60000
# 2   Delhi   55000

# %%
df8.loc[[1,2]]
# Out:
#    Name  Age    City  Salary
# 1  Neha   27  Mumbai   60000
# 2  Amit   29   Delhi   55000
