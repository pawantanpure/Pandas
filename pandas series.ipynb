# %% [markdown]
# import pandas as pd
# #  SERIES

# %%
labeled = ['a','b','c']
my_list = [1,2,3,4]

# %%
pd.Series(my_list)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series(labeled)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
dict = {1:11,2:22,3:33,4:44}
pd.Series(dict)
# Out:
# 1    11
# 2    22
# 3    33
# 4    44
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 0    <class 'dict'>
# dtype: object

# %%
data = {
    "name" : ["pawan","ritesh"],
    "age" :  ["14","20"]
}
pd.Series(data)
# Out:
# name    [pawan, ritesh]
# age            [14, 20]
# dtype: object

# %%
import pandas as pd

data = {
    "name": ["pawan", "ritesh"],
    "age": ["14", "20"]
}

df = pd.Series(data)
print(df)
# Out:
# name    [pawan, ritesh]
# age            [14, 20]
# dtype: object

# %% [markdown]
#   ## DataFrame

# %%
data = {
    "name": ['pawan','vaibhav','yogesh'],
    "age" : ['19','20','30'],
    "salary": ['2000','20000','2000000'],
    "city" : ['jalna','vodgao','partur',]
}
pd.DataFrame(data)
# Out:
#       name age   salary    city
# 0    pawan  19     2000   jalna
# 1  vaibhav  20    20000  vodgao
# 2   yogesh  30  2000000  partur

# %%
import pandas as pd
data_list = [
    ["pawan",10,2000,'solapur'],
    ["ritesh",12,4000,'partur'],
    [ "vaibhav",23,4000,'jalna'],
    [ "tejas",24,4000,'mantha']
]

df=pd.DataFrame(data_list,columns=["name","age","salary","city"])
df
# Out:
#       name  age  salary     city
# 0    pawan   10    2000  solapur
# 1   ritesh   12    4000   partur
# 2  vaibhav   23    4000    jalna
# 3    tejas   24    4000   mantha

# %%
df["city"]
# Out:
# 0    solapur
# 1     partur
# 2      jalna
# 3     mantha
# Name: city, dtype: object

# %%
df["name"]
# Out:
# 0      pawan
# 1     ritesh
# 2    vaibhav
# 3      tejas
# Name: name, dtype: object

# %%
df["destination"] = ["engg","doctor","farmer","worker"]
df
# Out:
#       name  age  salary     city id destination
# 0    pawan   10    2000  solapur  1        engg
# 1   ritesh   12    4000   partur  2      doctor
# 2  vaibhav   23    4000    jalna  3      farmer
# 3    tejas   24    4000   mantha  4      worker

# %%
df.drop("name",axis=1)
# Out:
#    age  salary     city id destination
# 0   10    2000  solapur  1        engg
# 1   12    4000   partur  2      doctor
# 2   23    4000    jalna  3      farmer
# 3   24    4000   mantha  4      worker

# %%
df.drop("salary",axis=1)
# Out:
#       name  age     city id destination
# 0    pawan   10  solapur  1        engg
# 1   ritesh   12   partur  2      doctor
# 2  vaibhav   23    jalna  3      farmer
# 3    tejas   24   mantha  4      worker
