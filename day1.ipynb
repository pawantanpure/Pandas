# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\tanpu\Downloads\data.xlsx")
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
print(df.columns)
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df_numerical_data=df[['BirthRate','Internetusers']]
df_categorial_data=df[['ContryName,'IncomeGroup']]

# %%
df

# %%
df=pd.read_excel(r"C:\Users\tanpu\Downloads\data.xlsx")
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[10:11]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10  Azerbaijan         AZE       18.3           58.7  Upper middle income

# %%
df[13:15]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 13         Benin         BEN     36.440            4.9  Low income
# 14  Burkina Faso         BFA     40.551            9.1  Low income

# %%
df[15:20]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# 17                 Bahrain         BHR     15.040       90.00004
# 18            Bahamas, The         BHS     15.339       72.00000
# 19  Bosnia and Herzegovina         BIH      9.062       57.79000
#
#             IncomeGroup
# 15  Lower middle income
# 16  Upper middle income
# 17          High income
# 18          High income
# 19  Upper middle income

# %%
df[0:100:20]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244          78.90          High income
# 20     Belarus         BLR     12.500          54.17  Upper middle income
# 40  Costa Rica         CRI     15.022          45.96  Upper middle income
# 60       Gabon         GAB     30.555           9.20  Upper middle income
# 80       India         IND     20.291          15.10  Lower middle income

# %%
df[::5]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244      78.900000
# 5                Argentina         ARG     17.716      59.900000
# 10              Azerbaijan         AZE     18.300      58.700000
# 15              Bangladesh         BGD     20.142       6.630000
# 20                 Belarus         BLR     12.500      54.170000
# 25                Barbados         BRB     12.188      73.000000
# 30                  Canada         CAN     10.900      85.800000
# 35                Cameroon         CMR     37.236       6.400000
# 40              Costa Rica         CRI     15.022      45.960000
# 45                 Germany         DEU      8.500      84.170000
# 50                 Ecuador         ECU     21.070      40.353684
# 55                Ethiopia         ETH     32.925       1.900000
# 60                   Gabon         GAB     30.555       9.200000
# ...

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[::10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
df[::-5]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 194                  Zimbabwe         ZWE     35.715        18.5000
# 189                     Samoa         WSM     26.172        15.3000
# 184             Venezuela, RB         VEN     19.842        54.9000
# 179                   Ukraine         UKR     11.100        41.0000
# 174       Trinidad and Tobago         TTO     14.590        63.8000
# 169                  Thailand         THA     11.041        28.9400
# 164                 Swaziland         SWZ     30.093        24.7000
# 159     Sao Tome and Principe         STP     34.537        23.0000
# 154              Sierra Leone         SLE     36.729         1.7000
# 149              Saudi Arabia         SAU     20.576        60.5000
# 144          French Polynesia         PYF     16.393        56.8000
# 139          Papua New Guinea         PNG     28.899         6.5000
# 134                      Oman         OMN     20.419        66.4500
# ...

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup  mycalc
# 0          False        False      False          False        False   False
# 1          False        False      False          False        False   False
# 2          False        False      False          False        False   False
# 3          False        False      False          False        False   False
# 4          False        False      False          False        False   False
# ..           ...          ...        ...            ...          ...     ...
# 190        False        False      False          False        False   False
# 191        False        False      False          False        False   False
# 192        False        False      False          False        False   False
# 193        False        False      False          False        False   False
# 194        False        False      False          False        False   False
#
# [195 rows x 6 columns]

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup  mycalc
# 0          False        False      False          False        False   False
# 1          False        False      False          False        False   False
# 2          False        False      False          False        False   False
# 3          False        False      False          False        False   False
# 4          False        False      False          False        False   False
# ..           ...          ...        ...            ...          ...     ...
# 190        False        False      False          False        False   False
# 191        False        False      False          False        False   False
# 192        False        False      False          False        False   False
# 193        False        False      False          False        False   False
# 194        False        False      False          False        False   False
#
# [195 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# mycalc           0
# dtype: int64

# %%
df

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# mycalc           0
# dtype: int64

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers       mycalc
# count  195.000000     195.000000   195.000000
# mean    21.469928      42.076471   653.559009
# std     10.605467      29.030788   351.553521
# min      7.900000       0.900000    28.990400
# 25%     12.120500      14.520000   361.263300
# 50%     19.680000      41.000000   682.074300
# 75%     29.759500      66.225000   892.690170
# max     49.661000      96.546800  1552.589500

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df_dategorical_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_dategorical_data
#
# NameError: name 'df_dategorical_data' is not defined

# %%
df.columns

# %%
df.columns=['a','b','c','d']
df.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.columns=['a','b','c','d']
#       2 df.columns
#
# File c:\Users\tanpu\anaconda3\Lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\tanpu\anaconda3\Lib\site-packages\pandas\core\generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
#     813 This is called from the cython code when we set the `index` attribute
#     814 directly, e.g. `series.index = [1, 2, 3]`.
#     815 """
#     816 labels = ensure_index(labels)
# --> 817 self._mgr.set_axis(axis, labels)
# ...

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'mycalc'],
#       dtype='object')

# %%
df['CountryCode']
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: CountryCode, Length: 195, dtype: object

# %%
df["mycalc"]=df.BirthRate*df.InternetUsers
df["mycalc"]
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Name: mycalc, Length: 195, dtype: float64

# %%
df["InternetUsers"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df[["IneternetUsers"]< 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[["IneternetUsers"]< 2]
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
len(df[df['InternetUsers']< 2])
# Out:
# 9

# %%
len(df[df["BirthRate"]> 40])
# Out:
# 12

# %%
df[(df]
# Out:
#   Cell In[10], line 1
#     df[(df]
#           ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
df[(df)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11712\4061233090.py in ?()
# ----> 1 df[(df)]
#
# c:\Users\tanpu\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4096             return self._getitem_slice(key)
#    4097
#    4098         # Do we have a (boolean) DataFrame?
#    4099         if isinstance(key, DataFrame):
# -> 4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
#
# c:\Users\tanpu\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   11044                         stacklevel=2,
#   11045                     )
#   11046
#   11047         other = common.apply_if_callable(other, self)
# > 11048         return self._where(cond, other, inplace, axis, level)
#
# ...
