# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_excel(r"C:\Users\tanpu\Downloads\data.xlsx")
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df=pd.read_excel(r"C:\Users\tanpu\Downloads\data.xlsx")
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
id(df)
# Out:
# 2235639592080

# %%
len(df)
# Out:
# 195

# %%
df.shape
# Out:
# (195, 5)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 5

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna
# Out:
# <bound method DataFrame.isna of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df.BirthRate*df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df['InternetUsers']<2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df['InternetUsers']<2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
df[df['InternetUsers']>2]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[df['InternetUsers']<20]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# 14       Burkina Faso         BFA     40.551            9.1
# ..                ...         ...        ...            ...
# 187           Vanuatu         VUT     26.739           11.3
# 189             Samoa         WSM     26.172           15.3
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# 187  Lower middle income
# 189  Lower middle income
# ...

# %%
df[df['InternetUsers']>20]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244           78.9
# 3                  Albania         ALB     12.877           57.2
# 4     United Arab Emirates         ARE     11.044           88.0
# 5                Argentina         ARG     17.716           59.9
# 6                  Armenia         ARM     13.308           41.9
# ..                     ...         ...        ...            ...
# 184          Venezuela, RB         VEN     19.842           54.9
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 188     West Bank and Gaza         PSE     30.394           46.6
# 191           South Africa         ZAF     20.850           46.5
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# ..                   ...
# ...

# %%
len(df[df['InternetUsers']<2])
# Out:
# 9

# %%
df[(df.BirthRate>40)&(df.InternetUsers<2)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
df[(df.BirthRate>4)&(df.InternetUsers<20)]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# 14       Burkina Faso         BFA     40.551            9.1
# ..                ...         ...        ...            ...
# 187           Vanuatu         VUT     26.739           11.3
# 189             Samoa         WSM     26.172           15.3
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# 187  Lower middle income
# 189  Lower middle income
# ...

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df.head(90)
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 0                  Aruba         ABW     10.244        78.9000
# 1            Afghanistan         AFG     35.253         5.9000
# 2                 Angola         AGO     45.985        19.1000
# 3                Albania         ALB     12.877        57.2000
# 4   United Arab Emirates         ARE     11.044        88.0000
# ..                   ...         ...        ...            ...
# 85                Israel         ISR     21.300        70.8000
# 86                 Italy         ITA      8.500        58.4593
# 87               Jamaica         JAM     13.540        37.1000
# 88                Jordan         JOR     27.046        41.0000
# 89                 Japan         JPN      8.200        89.7100
#
#             IncomeGroup
# 0           High income
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4           High income
# ..                  ...
# 85          High income
# ...

# %%
df.head(9)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
# 8             Australia         AUS     13.200           83.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income

# %%
df.tail(9)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 186             Vietnam         VNM     15.537           43.9
# 187             Vanuatu         VUT     26.739           11.3
# 188  West Bank and Gaza         PSE     30.394           46.6
# 189               Samoa         WSM     26.172           15.3
# 190         Yemen, Rep.         YEM     32.947           20.0
# 191        South Africa         ZAF     20.850           46.5
# 192    Congo, Dem. Rep.         COD     42.394            2.2
# 193              Zambia         ZMB     40.471           15.4
# 194            Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.tail(90)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 105         Lithuania         LTU     10.100        68.4529
# 106        Luxembourg         LUX     11.300        93.7765
# 107            Latvia         LVA     10.200        75.2344
# 108  Macao SAR, China         MAC     11.256        65.8000
# 109           Morocco         MAR     21.023        56.0000
# ..                ...         ...        ...            ...
# 190       Yemen, Rep.         YEM     32.947        20.0000
# 191      South Africa         ZAF     20.850        46.5000
# 192  Congo, Dem. Rep.         COD     42.394         2.2000
# 193            Zambia         ZMB     40.471        15.4000
# 194          Zimbabwe         ZWE     35.715        18.5000
#
#              IncomeGroup
# 105          High income
# 106          High income
# 107          High income
# 108          High income
# 109  Lower middle income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
df[1:20]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# 13                   Benin         BEN     36.440        4.90000
# ...

# %%
df[9:0]
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, BirthRate, InternetUsers, IncomeGroup]
# Index: []

# %%
df[9:90]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 9      Austria         AUT      9.400        80.6188          High income
# 10  Azerbaijan         AZE     18.300        58.7000  Upper middle income
# 11     Burundi         BDI     44.151         1.3000           Low income
# 12     Belgium         BEL     11.200        82.1702          High income
# 13       Benin         BEN     36.440         4.9000           Low income
# ..         ...         ...        ...            ...                  ...
# 85      Israel         ISR     21.300        70.8000          High income
# 86       Italy         ITA      8.500        58.4593          High income
# 87     Jamaica         JAM     13.540        37.1000  Upper middle income
# 88      Jordan         JOR     27.046        41.0000  Upper middle income
# 89       Japan         JPN      8.200        89.7100          High income
#
# [81 rows x 5 columns]

# %%
df[-1:10]
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, BirthRate, InternetUsers, IncomeGroup]
# Index: []

# %%
df[1:-12]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 1             Afghanistan         AFG     35.253           5.90
# 2                  Angola         AGO     45.985          19.10
# 3                 Albania         ALB     12.877          57.20
# 4    United Arab Emirates         ARE     11.044          88.00
# 5               Argentina         ARG     17.716          59.90
# ..                    ...         ...        ...            ...
# 178                Uganda         UGA     43.474          16.20
# 179               Ukraine         UKR     11.100          41.00
# 180               Uruguay         URY     14.374          57.69
# 181         United States         USA     12.500          84.20
# 182            Uzbekistan         UZB     22.500          38.20
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# ..                   ...
# ...

# %%
df[1:4]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income
# 3      Albania         ALB     12.877           57.2  Upper middle income

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
import pandas as pd

# %%
df2=pd.read_excel(r'C:\Users\tanpu\Downloads\data.xlsx')
df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
id(df2)
# Out:
# 1783352198992

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
pd.__version
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 pd.__version
#
# AttributeError: module 'pandas' has no attribute '__version'

# %%
len(df2)
# Out:
# 195

# %%
df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df2.head(3)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
df2.head(4)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income
# 3      Albania         ALB     12.877           57.2  Upper middle income

# %% [markdown]
# df2.head(5)

# %%
df2.head(6)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
df2.head(7)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
df2.head(9)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
# 7   Antigua and Barbuda         ATG     16.447           63.4
# 8             Australia         AUS     13.200           83.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income

# %%
df2.tail(4)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df2.tail(9)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 186             Vietnam         VNM     15.537           43.9
# 187             Vanuatu         VUT     26.739           11.3
# 188  West Bank and Gaza         PSE     30.394           46.6
# 189               Samoa         WSM     26.172           15.3
# 190         Yemen, Rep.         YEM     32.947           20.0
# 191        South Africa         ZAF     20.850           46.5
# 192    Congo, Dem. Rep.         COD     42.394            2.2
# 193              Zambia         ZMB     40.471           15.4
# 194            Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df2.tail(3)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df2.tail(4)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df2.tail(5)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df2.tail(6)
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 189             Samoa         WSM     26.172           15.3
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df2.tail(8)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 187             Vanuatu         VUT     26.739           11.3
# 188  West Bank and Gaza         PSE     30.394           46.6
# 189               Samoa         WSM     26.172           15.3
# 190         Yemen, Rep.         YEM     32.947           20.0
# 191        South Africa         ZAF     20.850           46.5
# 192    Congo, Dem. Rep.         COD     42.394            2.2
# 193              Zambia         ZMB     40.471           15.4
# 194            Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df2.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df2.columns)
# Out:
# 5

# %%
df2.dtypes

# %%
df2['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
df2["CountryCode"]
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: CountryCode, Length: 195, dtype: object

# %%
df2.dtypes

# %%
df2

# %%
df2[['BirthRate','InternetUsers']]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df2['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
df2['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
df2['CountryCode']
# Out:
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      ARE
#       ...
# 190    YEM
# 191    ZAF
# 192    COD
# 193    ZMB
# 194    ZWE
# Name: CountryCode, Length: 195, dtype: object

# %%
df2[['BirthRate','InternetUsers']]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df2_numerical_data=df2[['BirthRate','InternetUsers']]
df2_numerical_data
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df2_numerical_data=df2[['BirthRate','InternetUsers']]
df2_numerical_data
df2_categorical_data=df2[['CountryName','CountryCode','IncomeGroup']]
df2_categorical_data
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df2_categorical_data.head(4)
# Out:
#    CountryName CountryCode          IncomeGroup
# 0        Aruba         ABW          High income
# 1  Afghanistan         AFG           Low income
# 2       Angola         AGO  Upper middle income
# 3      Albania         ALB  Upper middle income

# %%
df2_categorical_data.tail(4)
# Out:
#           CountryName CountryCode          IncomeGroup
# 191      South Africa         ZAF  Upper middle income
# 192  Congo, Dem. Rep.         COD           Low income
# 193            Zambia         ZMB  Lower middle income
# 194          Zimbabwe         ZWE           Low income

# %%
df2_numerical_data.tail(9)
# Out:
#      BirthRate  InternetUsers
# 186     15.537           43.9
# 187     26.739           11.3
# 188     30.394           46.6
# 189     26.172           15.3
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5

# %%
df2_numerical_data.head(3)
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9
# 1     35.253            5.9
# 2     45.985           19.1

# %%
df2_categorical_data.head(4)
# Out:
#    CountryName CountryCode          IncomeGroup
# 0        Aruba         ABW          High income
# 1  Afghanistan         AFG           Low income
# 2       Angola         AGO  Upper middle income
# 3      Albania         ALB  Upper middle income

# %%
df2_numerical_data.tail(4)
# Out:
#      BirthRate  InternetUsers
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5

# %%
df2_categorical_data.head(4)
# Out:
#    CountryName CountryCode          IncomeGroup
# 0        Aruba         ABW          High income
# 1  Afghanistan         AFG           Low income
# 2       Angola         AGO  Upper middle income
# 3      Albania         ALB  Upper middle income

# %%
df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2.shape
# Out:
# (195, 5)

# %%
df2_numerical_data.shape
# Out:
# (195, 2)

# %%
df2_categorical_data.shape
# Out:
# (195, 3)

# %%
df2_numerical_data.columns
# Out:
# Index(['BirthRate', 'InternetUsers'], dtype='object')

# %%
df2_categorical_data.columns
# Out:
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='object')

# %%
df2_categorical_data.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\3900347707.py in ?()
# ----> 1 df2_categorical_data.rows
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2.BirthRate*InternetUsers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df2.BirthRate*InternetUsers
#
# NameError: name 'InternetUsers' is not defined

# %%
df2.BirthRate*df2.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df2.CountryName*df2.CountryCode
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2[1:4]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income
# 3      Albania         ALB     12.877           57.2  Upper middle income

# %%
df2[10:11]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10  Azerbaijan         AZE       18.3           58.7  Upper middle income

# %%
df2[1:94:10]
# Out:
#          CountryName CountryCode  BirthRate  InternetUsers  \
# 1        Afghanistan         AFG     35.253         5.9000
# 11           Burundi         BDI     44.151         1.3000
# 21            Belize         BLZ     23.092        33.6000
# 31       Switzerland         CHE     10.200        86.3400
# 41              Cuba         CUB     10.400        27.9300
# 51  Egypt, Arab Rep.         EGY     28.032        29.4000
# 61    United Kingdom         GBR     12.200        89.8441
# 71         Guatemala         GTM     27.465        19.7000
# 81           Ireland         IRL     15.000        78.2477
# 91             Kenya         KEN     35.194        39.0000
#
#             IncomeGroup
# 1            Low income
# 11           Low income
# 21  Upper middle income
# 31          High income
# 41  Upper middle income
# 51  Lower middle income
# 61          High income
# 71  Lower middle income
# 81          High income
# 91  Lower middle income

# %%
df2[1:94:5]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253         5.9000
# 6             Armenia         ARM     13.308        41.9000
# 11            Burundi         BDI     44.151         1.3000
# 16           Bulgaria         BGR      9.200        53.0615
# 21             Belize         BLZ     23.092        33.6000
# 26  Brunei Darussalam         BRN     16.405        64.5000
# 31        Switzerland         CHE     10.200        86.3400
# 36        Congo, Rep.         COG     37.011         6.6000
# 41               Cuba         CUB     10.400        27.9300
# 46           Djibouti         DJI     25.486         9.5000
# 51   Egypt, Arab Rep.         EGY     28.032        29.4000
# 56            Finland         FIN     10.700        91.5144
# 61     United Kingdom         GBR     12.200        89.8441
# 66      Guinea-Bissau         GNB     37.503         3.1000
# 71          Guatemala         GTM     27.465        19.7000
# ...

# %%
df2[20:90:7]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 20             Belarus         BLR     12.500        54.1700
# 27              Bhutan         BTN     18.134        29.9000
# 34       Cote d'Ivoire         CIV     37.320         8.4000
# 41                Cuba         CUB     10.400        27.9300
# 48  Dominican Republic         DOM     21.198        45.9000
# 55            Ethiopia         ETH     32.925         1.9000
# 62             Georgia         GEO     13.332        43.3000
# 69             Grenada         GRD     19.334        35.0000
# 76             Croatia         HRV      9.400        66.7476
# 83                Iraq         IRQ     31.093         9.2000
#
#             IncomeGroup
# 20  Upper middle income
# 27  Lower middle income
# 34  Lower middle income
# 41  Upper middle income
# 48  Upper middle income
# 55           Low income
# 62  Lower middle income
# 69  Upper middle income
# 76          High income
# 83  Upper middle income

# %%
df2[3:30:3]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 3        Albania         ALB     12.877        57.2000  Upper middle income
# 6        Armenia         ARM     13.308        41.9000  Lower middle income
# 9        Austria         AUT      9.400        80.6188          High income
# 12       Belgium         BEL     11.200        82.1702          High income
# 15    Bangladesh         BGD     20.142         6.6300  Lower middle income
# 18  Bahamas, The         BHS     15.339        72.0000          High income
# 21        Belize         BLZ     23.092        33.6000  Upper middle income
# 24        Brazil         BRA     14.931        51.0400  Upper middle income
# 27        Bhutan         BTN     18.134        29.9000  Lower middle income

# %%
df2[10:1]
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, BirthRate, InternetUsers, IncomeGroup]
# Index: []

# %%
df2[70:10:5]
# Out:
# Empty DataFrame
# Columns: [CountryName, CountryCode, BirthRate, InternetUsers, IncomeGroup]
# Index: []

# %%
df2[40:60:12]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 40  Costa Rica         CRI     15.022          45.96  Upper middle income
# 52     Eritrea         ERI     34.800           0.90           Low income

# %%
df2[30:50:10]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 30      Canada         CAN     10.900          85.80          High income
# 40  Costa Rica         CRI     15.022          45.96  Upper middle income

# %%
df2[::2]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 2                  Angola         AGO     45.985           19.1
# 4    United Arab Emirates         ARE     11.044           88.0
# 6                 Armenia         ARM     13.308           41.9
# 8               Australia         AUS     13.200           83.0
# ..                    ...         ...        ...            ...
# 186               Vietnam         VNM     15.537           43.9
# 188    West Bank and Gaza         PSE     30.394           46.6
# 190           Yemen, Rep.         YEM     32.947           20.0
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 2    Upper middle income
# 4            High income
# 6    Lower middle income
# 8            High income
# ..                   ...
# ...

# %%
df2[::1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2[::3]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244        78.9000
# 3                           Albania         ALB     12.877        57.2000
# 6                           Armenia         ARM     13.308        41.9000
# 9                           Austria         AUT      9.400        80.6188
# 12                          Belgium         BEL     11.200        82.1702
# ..                              ...         ...        ...            ...
# 180                         Uruguay         URY     14.374        57.6900
# 183  St. Vincent and the Grenadines         VCT     16.306        52.0000
# 186                         Vietnam         VNM     15.537        43.9000
# 189                           Samoa         WSM     26.172        15.3000
# 192                Congo, Dem. Rep.         COD     42.394         2.2000
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# ...

# %%
df2[::5]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244      78.900000
# 5                Argentina         ARG     17.716      59.900000
# 10              Azerbaijan         AZE     18.300      58.700000
# 15              Bangladesh         BGD     20.142       6.630000
# 20                 Belarus         BLR     12.500      54.170000
# 25                Barbados         BRB     12.188      73.000000
# 30                  Canada         CAN     10.900      85.800000
# 35                Cameroon         CMR     37.236       6.400000
# 40              Costa Rica         CRI     15.022      45.960000
# 45                 Germany         DEU      8.500      84.170000
# 50                 Ecuador         ECU     21.070      40.353684
# 55                Ethiopia         ETH     32.925       1.900000
# 60                   Gabon         GAB     30.555       9.200000
# ...

# %%
df2[::10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
df2[::-2]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 190           Yemen, Rep.         YEM     32.947           20.0
# 188    West Bank and Gaza         PSE     30.394           46.6
# 186               Vietnam         VNM     15.537           43.9
# ..                    ...         ...        ...            ...
# 8               Australia         AUS     13.200           83.0
# 6                 Armenia         ARM     13.308           41.9
# 4    United Arab Emirates         ARE     11.044           88.0
# 2                  Angola         AGO     45.985           19.1
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 192           Low income
# 190  Lower middle income
# 188  Lower middle income
# 186  Lower middle income
# ..                   ...
# ...

# %%
df2.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df2.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df2.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df2.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df2.max()
# Out:
# CountryName                 Zimbabwe
# CountryCode                      ZWE
# BirthRate                     49.661
# InternetUsers                96.5468
# IncomeGroup      Upper middle income
# dtype: object

# %%
df2.min()
# Out:
# CountryName      Afghanistan
# CountryCode              ABW
# BirthRate                7.9
# InternetUsers            0.9
# IncomeGroup      High income
# dtype: object

# %%
df2
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2_categorical_data.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df2_numerical_data.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df2.BirthRate*df2.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df2[10:16]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10    Azerbaijan         AZE     18.300        58.7000  Upper middle income
# 11       Burundi         BDI     44.151         1.3000           Low income
# 12       Belgium         BEL     11.200        82.1702          High income
# 13         Benin         BEN     36.440         4.9000           Low income
# 14  Burkina Faso         BFA     40.551         9.1000           Low income
# 15    Bangladesh         BGD     20.142         6.6300  Lower middle income

# %%
df2[40:44]
# Out:
#        CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 40      Costa Rica         CRI     15.022        45.9600  Upper middle income
# 41            Cuba         CUB     10.400        27.9300  Upper middle income
# 42  Cayman Islands         CYM     12.500        74.1000          High income
# 43          Cyprus         CYP     11.436        65.4548          High income

# %%
df2[::3]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244        78.9000
# 3                           Albania         ALB     12.877        57.2000
# 6                           Armenia         ARM     13.308        41.9000
# 9                           Austria         AUT      9.400        80.6188
# 12                          Belgium         BEL     11.200        82.1702
# ..                              ...         ...        ...            ...
# 180                         Uruguay         URY     14.374        57.6900
# 183  St. Vincent and the Grenadines         VCT     16.306        52.0000
# 186                         Vietnam         VNM     15.537        43.9000
# 189                           Samoa         WSM     26.172        15.3000
# 192                Congo, Dem. Rep.         COD     42.394         2.2000
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# ...

# %%
df[df['InternetUsers']<2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
df2[df2['InternetUsers']<1]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 52     Eritrea         ERI       34.8            0.9  Low income

# %%
df2[df2['BirthRate']>3]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df2[df2['BirthRate']<40.342]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# ..                    ...         ...        ...            ...
# 188    West Bank and Gaza         PSE     30.394           46.6
# 189                 Samoa         WSM     26.172           15.3
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 3    Upper middle income
# 4            High income
# 5            High income
# ..                   ...
# ...

# %%
df2[df2['InternetUsers']<4]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 117                   Myanmar         MMR     18.119            1.6
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# 156                   Somalia         SOM     43.891            1.5
# ...
