# %%
import pandas as pd

# %%
import numpy as np

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isnull()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.fillna(7)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  7.0
# 2  7.0  3  3.0  7.0
# 3  4.0  4  7.0  7.0
# 4  5.0  5  7.0  5.0

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
p=df.fillna(9)
p
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  9.0
# 2  9.0  3  3.0  9.0
# 3  4.0  4  9.0  9.0
# 4  5.0  5  9.0  5.0

# %%
p.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  9.0
# 2  9.0  3  3.0  9.0
# 3  4.0  4  9.0  9.0
# 4  5.0  5  9.0  5.0

# %%
df.dropna(thresh=1)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(8)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  8.0
# 2  8.0  3  3.0  8.0
# 3  4.0  4  8.0  8.0
# 4  5.0  5  8.0  5.0

# %%
values={'A':0,'B':100,'C':200,'D':300}
df.fillna(value=values)
# Out:
#      A  B      C      D
# 0  1.0  1    1.0    1.0
# 1  2.0  2    2.0  300.0
# 2  0.0  3    3.0  300.0
# 3  4.0  4  200.0  300.0
# 4  5.0  5  200.0    5.0

# %%
values={'A':'pawan','B':'anna','C':'ravi','D':'shiv'}
df.fillna(value=values)
# Out:
#        A  B     C     D
# 0    1.0  1   1.0   1.0
# 1    2.0  2   2.0  shiv
# 2  pawan  3   3.0  shiv
# 3    4.0  4  ravi  shiv
# 4    5.0  5  ravi   5.0

# %%
df.fillna(df.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %%
df.fillna(df.max())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  5.0
# 2  5.0  3  3.0  5.0
# 3  4.0  4  3.0  5.0
# 4  5.0  5  3.0  5.0
